# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME ../../
# %cd ../../
# %cd cs231n/datasets/
# !bash get_datasets.sh
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content
# /content/cs231n/datasets
# --2020-12-24 05:05:14--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  57.4MB/s    in 2.8s
#
# 2020-12-24 05:05:17 (57.4 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /content

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.400254
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Under the untrained, prob is near 1/10. cost function = -SUM(t * log(p))*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.027453 analytic: 1.027453, relative error: 7.001230e-09
# numerical: -2.373417 analytic: -2.373417, relative error: 8.402157e-09
# numerical: -2.947733 analytic: -2.947733, relative error: 7.665693e-09
# numerical: -0.779179 analytic: -0.779179, relative error: 1.436127e-08
# numerical: 2.460034 analytic: 2.460034, relative error: 2.949639e-08
# numerical: 2.521065 analytic: 2.521064, relative error: 1.570273e-08
# numerical: -0.299583 analytic: -0.299583, relative error: 6.210563e-09
# numerical: 0.593310 analytic: 0.593310, relative error: 9.705402e-10
# numerical: 1.042997 analytic: 1.042997, relative error: 2.645130e-08
# numerical: 0.768836 analytic: 0.768836, relative error: 3.836215e-09
# numerical: 0.691891 analytic: 0.691891, relative error: 1.245547e-09
# numerical: 0.953513 analytic: 0.953513, relative error: 3.991732e-08
# numerical: -2.375713 analytic: -2.375713, relative error: 1.996271e-09
# numerical: 1.290095 analytic: 1.290094, relative error: 5.343806e-08
# numerical: -4.132659 analytic: -4.132659, relative error: 1.454201e-09
# numerical: 4.086391 analytic: 4.086391, relative error: 1.624347e-08
# numerical: 0.526368 analytic: 0.526368, relative error: 9.422238e-08
# numerical: 2.062679 analytic: 2.062679, relative error: 4.516588e-08
# numerical: -2.290487 analytic: -2.290487, relative error: 8.542636e-10
# numerical: -0.523263 analytic: -0.523263, relative error: 9.927214e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.400254e+00 computed in 0.140707s
# vectorized loss: 2.400254e+00 computed in 0.012270s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

lr_list = np.linspace(1e-7, 5e-7, 5)
reg_list = np.linspace(2.5e4, 5e4, 5)
np.random.shuffle(lr_list)
np.random.shuffle(reg_list)
lr_reg_list = [(lr, reg) for lr in lr_list for reg in reg_list]

for (lr, reg) in lr_reg_list:
  softmax = Softmax()
  softmax.train(X_train, y_train, lr, reg,
                1500, verbose=True)
  y_t_pred = softmax.predict(X_train)
  y_v_pred = softmax.predict(X_val)
  
  train_acc = np.mean(y_t_pred == y_train)
  val_acc = np.mean(y_v_pred == y_val)
  results[(lr, reg)] = (train_acc, val_acc)
  print(f'lr:{lr} reg:{reg} T:{train_acc:.3f} V:{val_acc:.3f}')

  if val_acc > best_val:
    best_val = val_acc
    best_softmax = softmax

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 1527.625704
# iteration 100 / 1500: loss 28.839796
# iteration 200 / 1500: loss 2.620020
# iteration 300 / 1500: loss 2.150150
# iteration 400 / 1500: loss 2.147649
# iteration 500 / 1500: loss 2.170096
# iteration 600 / 1500: loss 2.140189
# iteration 700 / 1500: loss 2.097781
# iteration 800 / 1500: loss 2.180409
# iteration 900 / 1500: loss 2.131687
# iteration 1000 / 1500: loss 2.107457
# iteration 1100 / 1500: loss 2.152949
# iteration 1200 / 1500: loss 2.138656
# iteration 1300 / 1500: loss 2.121425
# iteration 1400 / 1500: loss 2.122089
# lr:2e-07 reg:50000.0 T:0.310 V:0.329
# iteration 0 / 1500: loss 768.101914
# iteration 100 / 1500: loss 103.947160
# iteration 200 / 1500: loss 15.690560
# iteration 300 / 1500: loss 3.849685
# iteration 400 / 1500: loss 2.313903
# iteration 500 / 1500: loss 2.133407
# iteration 600 / 1500: loss 2.113571
# iteration 700 / 1500: loss 2.116389
# iteration 800 / 1500: loss 2.086530
# iteration 900 / 1500: loss 2.101915
# iteration 1000 / 1500: loss 2.092443
# iteration 1100 / 1500: loss 2.083023
# iteration 1200 / 1500: loss 2.111275
# iteration 1300 / 1500: loss 2.073525
# iteration 1400 / 1500: loss 2.151439
# lr:2e-07 reg:25000.0 T:0.331 V:0.347
# iteration 0 / 1500: loss 965.564787
# iteration 100 / 1500: loss 79.357453
# iteration 200 / 1500: loss 8.357109
# iteration 300 / 1500: loss 2.665018
# iteration 400 / 1500: loss 2.128616
# iteration 500 / 1500: loss 2.137553
# iteration 600 / 1500: loss 2.060188
# iteration 700 / 1500: loss 2.128028
# iteration 800 / 1500: loss 2.072737
# iteration 900 / 1500: loss 2.125696
# iteration 1000 / 1500: loss 2.142770
# iteration 1100 / 1500: loss 2.068263
# iteration 1200 / 1500: loss 2.086620
# iteration 1300 / 1500: loss 2.072917
# iteration 1400 / 1500: loss 2.100627
# lr:2e-07 reg:31250.0 T:0.321 V:0.335
# iteration 0 / 1500: loss 1146.745997
# iteration 100 / 1500: loss 57.435346
# iteration 200 / 1500: loss 4.823837
# iteration 300 / 1500: loss 2.209775
# iteration 400 / 1500: loss 2.120136
# iteration 500 / 1500: loss 2.123762
# iteration 600 / 1500: loss 2.078776
# iteration 700 / 1500: loss 2.087237
# iteration 800 / 1500: loss 2.128685
# iteration 900 / 1500: loss 2.108580
# iteration 1000 / 1500: loss 2.121338
# iteration 1100 / 1500: loss 2.131193
# iteration 1200 / 1500: loss 2.147350
# iteration 1300 / 1500: loss 2.104888
# iteration 1400 / 1500: loss 2.126249
# lr:2e-07 reg:37500.0 T:0.318 V:0.328
# iteration 0 / 1500: loss 1348.181184
# iteration 100 / 1500: loss 41.236756
# iteration 200 / 1500: loss 3.291048
# iteration 300 / 1500: loss 2.172065
# iteration 400 / 1500: loss 2.105244
# iteration 500 / 1500: loss 2.107088
# iteration 600 / 1500: loss 2.175683
# iteration 700 / 1500: loss 2.166343
# iteration 800 / 1500: loss 2.107882
# iteration 900 / 1500: loss 2.076247
# iteration 1000 / 1500: loss 2.144974
# iteration 1100 / 1500: loss 2.111540
# iteration 1200 / 1500: loss 2.153929
# iteration 1300 / 1500: loss 2.144939
# iteration 1400 / 1500: loss 2.154270
# lr:2e-07 reg:43750.0 T:0.305 V:0.319
# iteration 0 / 1500: loss 1530.466233
# iteration 100 / 1500: loss 2.539151
# iteration 200 / 1500: loss 2.090609
# iteration 300 / 1500: loss 2.142487
# iteration 400 / 1500: loss 2.166180
# iteration 500 / 1500: loss 2.148937
# iteration 600 / 1500: loss 2.167664
# iteration 700 / 1500: loss 2.127895
# iteration 800 / 1500: loss 2.180453
# iteration 900 / 1500: loss 2.168956
# iteration 1000 / 1500: loss 2.163036
# iteration 1100 / 1500: loss 2.102297
# iteration 1200 / 1500: loss 2.114564
# iteration 1300 / 1500: loss 2.140911
# iteration 1400 / 1500: loss 2.140968
# lr:4e-07 reg:50000.0 T:0.313 V:0.332
# iteration 0 / 1500: loss 772.054992
# iteration 100 / 1500: loss 15.450240
# iteration 200 / 1500: loss 2.295007
# iteration 300 / 1500: loss 2.067847
# iteration 400 / 1500: loss 2.083276
# iteration 500 / 1500: loss 2.075636
# iteration 600 / 1500: loss 2.010714
# iteration 700 / 1500: loss 2.060561
# iteration 800 / 1500: loss 2.125604
# iteration 900 / 1500: loss 2.092796
# iteration 1000 / 1500: loss 2.053153
# iteration 1100 / 1500: loss 2.154776
# iteration 1200 / 1500: loss 2.156055
# iteration 1300 / 1500: loss 2.034782
# iteration 1400 / 1500: loss 2.084560
# lr:4e-07 reg:25000.0 T:0.320 V:0.333
# iteration 0 / 1500: loss 966.979484
# iteration 100 / 1500: loss 8.165913
# iteration 200 / 1500: loss 2.161516
# iteration 300 / 1500: loss 2.108654
# iteration 400 / 1500: loss 2.124209
# iteration 500 / 1500: loss 2.090538
# iteration 600 / 1500: loss 2.079003
# iteration 700 / 1500: loss 2.110023
# iteration 800 / 1500: loss 2.041296
# iteration 900 / 1500: loss 2.082053
# iteration 1000 / 1500: loss 2.104523
# iteration 1100 / 1500: loss 2.133233
# iteration 1200 / 1500: loss 2.165344
# iteration 1300 / 1500: loss 2.102117
# iteration 1400 / 1500: loss 2.079166
# lr:4e-07 reg:31250.0 T:0.323 V:0.328
# iteration 0 / 1500: loss 1147.289565
# iteration 100 / 1500: loss 4.689847
# iteration 200 / 1500: loss 2.128312
# iteration 300 / 1500: loss 2.044729
# iteration 400 / 1500: loss 2.133340
# iteration 500 / 1500: loss 2.116771
# iteration 600 / 1500: loss 2.130302
# iteration 700 / 1500: loss 2.109220
# iteration 800 / 1500: loss 2.121351
# iteration 900 / 1500: loss 2.162650
# iteration 1000 / 1500: loss 2.107673
# iteration 1100 / 1500: loss 2.172463
# iteration 1200 / 1500: loss 2.148930
# iteration 1300 / 1500: loss 2.177628
# iteration 1400 / 1500: loss 2.111184
# lr:4e-07 reg:37500.0 T:0.322 V:0.345
# iteration 0 / 1500: loss 1356.997731
# iteration 100 / 1500: loss 3.234106
# iteration 200 / 1500: loss 2.166762
# iteration 300 / 1500: loss 2.171972
# iteration 400 / 1500: loss 2.128911
# iteration 500 / 1500: loss 2.159846
# iteration 600 / 1500: loss 2.106314
# iteration 700 / 1500: loss 2.150225
# iteration 800 / 1500: loss 2.099100
# iteration 900 / 1500: loss 2.174781
# iteration 1000 / 1500: loss 2.131999
# iteration 1100 / 1500: loss 2.135987
# iteration 1200 / 1500: loss 2.165764
# iteration 1300 / 1500: loss 2.126006
# iteration 1400 / 1500: loss 2.179097
# lr:4e-07 reg:43750.0 T:0.309 V:0.308
# iteration 0 / 1500: loss 1528.234148
# iteration 100 / 1500: loss 5.537762
# iteration 200 / 1500: loss 2.212468
# iteration 300 / 1500: loss 2.119301
# iteration 400 / 1500: loss 2.138616
# iteration 500 / 1500: loss 2.157285
# iteration 600 / 1500: loss 2.124752
# iteration 700 / 1500: loss 2.141609
# iteration 800 / 1500: loss 2.098297
# iteration 900 / 1500: loss 2.173836
# iteration 1000 / 1500: loss 2.152017
# iteration 1100 / 1500: loss 2.143838
# iteration 1200 / 1500: loss 2.165808
# iteration 1300 / 1500: loss 2.124769
# iteration 1400 / 1500: loss 2.161749
# lr:3e-07 reg:50000.0 T:0.310 V:0.335
# iteration 0 / 1500: loss 785.921536
# iteration 100 / 1500: loss 39.832994
# iteration 200 / 1500: loss 3.982866
# iteration 300 / 1500: loss 2.216455
# iteration 400 / 1500: loss 2.087846
# iteration 500 / 1500: loss 2.106985
# iteration 600 / 1500: loss 2.067750
# iteration 700 / 1500: loss 2.123706
# iteration 800 / 1500: loss 2.064795
# iteration 900 / 1500: loss 2.108025
# iteration 1000 / 1500: loss 2.120915
# iteration 1100 / 1500: loss 2.090476
# iteration 1200 / 1500: loss 2.132806
# iteration 1300 / 1500: loss 2.108201
# iteration 1400 / 1500: loss 2.080273
# lr:3e-07 reg:25000.0 T:0.328 V:0.353
# iteration 0 / 1500: loss 967.117036
# iteration 100 / 1500: loss 23.844676
# iteration 200 / 1500: loss 2.611374
# iteration 300 / 1500: loss 2.139439
# iteration 400 / 1500: loss 2.134018
# iteration 500 / 1500: loss 2.156481
# iteration 600 / 1500: loss 2.137903
# iteration 700 / 1500: loss 2.125201
# iteration 800 / 1500: loss 2.122058
# iteration 900 / 1500: loss 2.063909
# iteration 1000 / 1500: loss 2.156530
# iteration 1100 / 1500: loss 2.065609
# iteration 1200 / 1500: loss 2.120303
# iteration 1300 / 1500: loss 2.090212
# iteration 1400 / 1500: loss 2.078573
# lr:3e-07 reg:31250.0 T:0.327 V:0.340
# iteration 0 / 1500: loss 1151.853206
# iteration 100 / 1500: loss 14.157922
# iteration 200 / 1500: loss 2.228992
# iteration 300 / 1500: loss 2.108194
# iteration 400 / 1500: loss 2.126416
# iteration 500 / 1500: loss 2.078860
# iteration 600 / 1500: loss 2.151763
# iteration 700 / 1500: loss 2.125762
# iteration 800 / 1500: loss 2.076611
# iteration 900 / 1500: loss 2.095573
# iteration 1000 / 1500: loss 2.031824
# iteration 1100 / 1500: loss 2.145359
# iteration 1200 / 1500: loss 2.136835
# iteration 1300 / 1500: loss 2.137657
# iteration 1400 / 1500: loss 2.127201
# lr:3e-07 reg:37500.0 T:0.311 V:0.325
# iteration 0 / 1500: loss 1352.852904
# iteration 100 / 1500: loss 8.714549
# iteration 200 / 1500: loss 2.169414
# iteration 300 / 1500: loss 2.120239
# iteration 400 / 1500: loss 2.153533
# iteration 500 / 1500: loss 2.129973
# iteration 600 / 1500: loss 2.138233
# iteration 700 / 1500: loss 2.186195
# iteration 800 / 1500: loss 2.153269
# iteration 900 / 1500: loss 2.121080
# iteration 1000 / 1500: loss 2.146930
# iteration 1100 / 1500: loss 2.125790
# iteration 1200 / 1500: loss 2.144543
# iteration 1300 / 1500: loss 2.163654
# iteration 1400 / 1500: loss 2.162721
# lr:3e-07 reg:43750.0 T:0.316 V:0.330
# iteration 0 / 1500: loss 1546.753329
# iteration 100 / 1500: loss 2.185681
# iteration 200 / 1500: loss 2.136198
# iteration 300 / 1500: loss 2.156715
# iteration 400 / 1500: loss 2.159763
# iteration 500 / 1500: loss 2.181746
# iteration 600 / 1500: loss 2.172024
# iteration 700 / 1500: loss 2.076440
# iteration 800 / 1500: loss 2.165648
# iteration 900 / 1500: loss 2.157923
# iteration 1000 / 1500: loss 2.152852
# iteration 1100 / 1500: loss 2.140567
# iteration 1200 / 1500: loss 2.145181
# iteration 1300 / 1500: loss 2.139940
# iteration 1400 / 1500: loss 2.147912
# lr:5e-07 reg:50000.0 T:0.313 V:0.335
# iteration 0 / 1500: loss 762.933838
# iteration 100 / 1500: loss 6.852349
# iteration 200 / 1500: loss 2.134470
# iteration 300 / 1500: loss 2.117451
# iteration 400 / 1500: loss 2.102614
# iteration 500 / 1500: loss 2.099959
# iteration 600 / 1500: loss 2.147308
# iteration 700 / 1500: loss 2.059265
# iteration 800 / 1500: loss 2.098344
# iteration 900 / 1500: loss 2.141843
# iteration 1000 / 1500: loss 2.075780
# iteration 1100 / 1500: loss 2.082601
# iteration 1200 / 1500: loss 2.127144
# iteration 1300 / 1500: loss 2.097849
# iteration 1400 / 1500: loss 2.090344
# lr:5e-07 reg:25000.0 T:0.321 V:0.351
# iteration 0 / 1500: loss 952.095289
# iteration 100 / 1500: loss 3.817411
# iteration 200 / 1500: loss 2.076310
# iteration 300 / 1500: loss 2.160416
# iteration 400 / 1500: loss 2.122115
# iteration 500 / 1500: loss 2.105049
# iteration 600 / 1500: loss 2.187014
# iteration 700 / 1500: loss 2.077309
# iteration 800 / 1500: loss 2.069132
# iteration 900 / 1500: loss 2.154888
# iteration 1000 / 1500: loss 2.148851
# iteration 1100 / 1500: loss 2.124794
# iteration 1200 / 1500: loss 2.110502
# iteration 1300 / 1500: loss 2.156094
# iteration 1400 / 1500: loss 2.117835
# lr:5e-07 reg:31250.0 T:0.317 V:0.325
# iteration 0 / 1500: loss 1188.705365
# iteration 100 / 1500: loss 2.674770
# iteration 200 / 1500: loss 2.092416
# iteration 300 / 1500: loss 2.056162
# iteration 400 / 1500: loss 2.117478
# iteration 500 / 1500: loss 2.100696
# iteration 600 / 1500: loss 2.133874
# iteration 700 / 1500: loss 2.114306
# iteration 800 / 1500: loss 2.079446
# iteration 900 / 1500: loss 2.119354
# iteration 1000 / 1500: loss 2.112503
# iteration 1100 / 1500: loss 2.083591
# iteration 1200 / 1500: loss 2.105826
# iteration 1300 / 1500: loss 2.135301
# iteration 1400 / 1500: loss 2.133164
# lr:5e-07 reg:37500.0 T:0.318 V:0.330
# iteration 0 / 1500: loss 1348.892217
# iteration 100 / 1500: loss 2.355750
# iteration 200 / 1500: loss 2.138696
# iteration 300 / 1500: loss 2.197578
# iteration 400 / 1500: loss 2.116017
# iteration 500 / 1500: loss 2.131868
# iteration 600 / 1500: loss 2.098351
# iteration 700 / 1500: loss 2.113775
# iteration 800 / 1500: loss 2.086306
# iteration 900 / 1500: loss 2.150280
# iteration 1000 / 1500: loss 2.138206
# iteration 1100 / 1500: loss 2.132487
# iteration 1200 / 1500: loss 2.091728
# iteration 1300 / 1500: loss 2.126752
# iteration 1400 / 1500: loss 2.143990
# lr:5e-07 reg:43750.0 T:0.304 V:0.323
# iteration 0 / 1500: loss 1558.123386
# iteration 100 / 1500: loss 210.117565
# iteration 200 / 1500: loss 29.911733
# iteration 300 / 1500: loss 5.868601
# iteration 400 / 1500: loss 2.644616
# iteration 500 / 1500: loss 2.230205
# iteration 600 / 1500: loss 2.190221
# iteration 700 / 1500: loss 2.121406
# iteration 800 / 1500: loss 2.153215
# iteration 900 / 1500: loss 2.152594
# iteration 1000 / 1500: loss 2.137762
# iteration 1100 / 1500: loss 2.137521
# iteration 1200 / 1500: loss 2.136989
# iteration 1300 / 1500: loss 2.128757
# iteration 1400 / 1500: loss 2.163263
# lr:1e-07 reg:50000.0 T:0.301 V:0.314
# iteration 0 / 1500: loss 763.893769
# iteration 100 / 1500: loss 280.064808
# iteration 200 / 1500: loss 103.949858
# iteration 300 / 1500: loss 39.335640
# iteration 400 / 1500: loss 15.645685
# iteration 500 / 1500: loss 7.110207
# iteration 600 / 1500: loss 3.913907
# iteration 700 / 1500: loss 2.745359
# iteration 800 / 1500: loss 2.309337
# iteration 900 / 1500: loss 2.188858
# iteration 1000 / 1500: loss 2.169404
# iteration 1100 / 1500: loss 2.036932
# iteration 1200 / 1500: loss 2.090042
# iteration 1300 / 1500: loss 2.085268
# iteration 1400 / 1500: loss 2.128475
# lr:1e-07 reg:25000.0 T:0.327 V:0.342
# iteration 0 / 1500: loss 960.978952
# iteration 100 / 1500: loss 274.707597
# iteration 200 / 1500: loss 79.678496
# iteration 300 / 1500: loss 24.146971
# iteration 400 / 1500: loss 8.348665
# iteration 500 / 1500: loss 3.892417
# iteration 600 / 1500: loss 2.640969
# iteration 700 / 1500: loss 2.284444
# iteration 800 / 1500: loss 2.162519
# iteration 900 / 1500: loss 2.150226
# iteration 1000 / 1500: loss 2.109230
# iteration 1100 / 1500: loss 2.123871
# iteration 1200 / 1500: loss 2.119068
# iteration 1300 / 1500: loss 2.104454
# iteration 1400 / 1500: loss 2.091495
# lr:1e-07 reg:31250.0 T:0.329 V:0.343
# iteration 0 / 1500: loss 1169.420754
# iteration 100 / 1500: loss 260.069984
# iteration 200 / 1500: loss 59.203575
# iteration 300 / 1500: loss 14.737451
# iteration 400 / 1500: loss 4.873941
# iteration 500 / 1500: loss 2.789755
# iteration 600 / 1500: loss 2.298728
# iteration 700 / 1500: loss 2.191301
# iteration 800 / 1500: loss 2.153666
# iteration 900 / 1500: loss 2.079773
# iteration 1000 / 1500: loss 2.142734
# iteration 1100 / 1500: loss 2.116501
# iteration 1200 / 1500: loss 2.113730
# iteration 1300 / 1500: loss 2.097327
# iteration 1400 / 1500: loss 2.091377
# lr:1e-07 reg:37500.0 T:0.318 V:0.342
# iteration 0 / 1500: loss 1352.282413
# iteration 100 / 1500: loss 233.839155
# iteration 200 / 1500: loss 41.953152
# iteration 300 / 1500: loss 9.009025
# iteration 400 / 1500: loss 3.308708
# iteration 500 / 1500: loss 2.331972
# iteration 600 / 1500: loss 2.188151
# iteration 700 / 1500: loss 2.139812
# iteration 800 / 1500: loss 2.140208
# iteration 900 / 1500: loss 2.179525
# iteration 1000 / 1500: loss 2.142578
# iteration 1100 / 1500: loss 2.142932
# iteration 1200 / 1500: loss 2.083011
# iteration 1300 / 1500: loss 2.098441
# iteration 1400 / 1500: loss 2.198721
# lr:1e-07 reg:43750.0 T:0.309 V:0.335
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.326571 val accuracy: 0.342000
# lr 1.000000e-07 reg 3.125000e+04 train accuracy: 0.329020 val accuracy: 0.343000
# lr 1.000000e-07 reg 3.750000e+04 train accuracy: 0.317551 val accuracy: 0.342000
# lr 1.000000e-07 reg 4.375000e+04 train accuracy: 0.308714 val accuracy: 0.335000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.301367 val accuracy: 0.314000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.330980 val accuracy: 0.347000
# lr 2.000000e-07 reg 3.125000e+04 train accuracy: 0.320816 val accuracy: 0.335000
# lr 2.000000e-07 reg 3.750000e+04 train accuracy: 0.318469 val accuracy: 0.328000
# lr 2.000000e-07 reg 4.375000e+04 train accuracy: 0.304837 val accuracy: 0.319000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.309531 val accuracy: 0.329000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.328347 val accuracy: 0.353000
# lr 3.000000e-07 reg 3.125000e+04 train accuracy: 0.326612 val accuracy: 0.340000
# lr 3.000000e-07 reg 3.750000e+04 train accuracy: 0.310735 val accuracy: 0.325000
# lr 3.000000e-07 reg 4.375000e+04 train accuracy: 0.316408 val accuracy: 0.330000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.310204 val accuracy: 0.335000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.319939 val accuracy: 0.333000
# lr 4.000000e-07 reg 3.125000e+04 train accuracy: 0.322653 val accuracy: 0.328000
# lr 4.000000e-07 reg 3.750000e+04 train accuracy: 0.321755 val accuracy: 0.345000
# lr 4.000000e-07 reg 4.375000e+04 train accuracy: 0.309082 val accuracy: 0.308000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.312837 val accuracy: 0.332000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.321286 val accuracy: 0.351000
# lr 5.000000e-07 reg 3.125000e+04 train accuracy: 0.317286 val accuracy: 0.325000
# lr 5.000000e-07 reg 3.750000e+04 train accuracy: 0.318306 val accuracy: 0.330000
# lr 5.000000e-07 reg 4.375000e+04 train accuracy: 0.303571 val accuracy: 0.323000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.313041 val accuracy: 0.335000
# best validation accuracy achieved during cross-validation: 0.353000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.341000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ---
# # IMPORTANT
#
# This is the end of this question. Please do the following:
#
# 1. Click `File -> Save` to make sure the latest checkpoint of this notebook is saved to your Drive.
# 2. Execute the cell below to download the modified `.py` files back to your drive.

# %%
import os
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'
FOLDER_TO_SAVE = os.path.join('drive/My Drive/', FOLDERNAME)
FILES_TO_SAVE = ['cs231n/classifiers/softmax.py']

for files in FILES_TO_SAVE:
  with open(os.path.join(FOLDER_TO_SAVE, '/'.join(files.split('/')[1:])), 'w') as f:
    f.write(''.join(open(files).readlines()))
